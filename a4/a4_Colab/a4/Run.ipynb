# %%
import os
import warnings
os.chdir('/content/drive/My Drive/src/cs224n/a4')
warnings.filterwarnings("ignore")

# %%
# !sh run.sh vocab
# Out:
# read in source sentences: ./en_es_data/train.es
# read in target sentences: ./en_es_data/train.en
# initialize source vocabulary ..
# number of word types: 172418, number of word types w/ frequency >= 2: 80623
# initialize target vocabulary ..
# number of word types: 128873, number of word types w/ frequency >= 2: 64215
# generated vocabulary, source 50004 words, target 50002 words
# vocabulary saved to vocab.json

# %%
# !pip install -r gpu_requirements.txt

# %%
# !sh run.sh train_local

# %%
# !sh run.sh test_local
# Out:
# load test source sentences from [./en_es_data/test.es]
# load test target sentences from [./en_es_data/test.en]
# load model from model.bin
# Decoding:   0% 0/8064 [00:00<?, ?it/s]/pytorch/aten/src/ATen/native/BinaryOps.cpp:81: UserWarning: Integer division of tensors using div or / is deprecated, and in a future release div will perform true division as in Python 3. Use true_divide or floor_divide (// in Python) instead.
# Decoding: 100% 8064/8064 [25:18<00:00,  5.31it/s]
# Corpus BLEU: 22.451681900342653
# Traceback (most recent call last):
#   File "run.py", line 344, in <module>
#     main()
#   File "run.py", line 338, in main
#     decode(args)
#   File "run.py", line 289, in decode
#     with open(args['OUTPUT_FILE'], 'w') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'outputs/test_outputs.txt'

# %%
# !sh run.sh train
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# epoch 6, iter 35200, avg. loss 30.93, avg. ppl 5.77 cum. examples 38400, speed 8214.64 words/sec, time elapsed 2566.28 sec
# epoch 6, iter 35210, avg. loss 32.41, avg. ppl 6.31 cum. examples 38720, speed 7586.89 words/sec, time elapsed 2567.03 sec
# epoch 6, iter 35220, avg. loss 34.26, avg. ppl 6.63 cum. examples 39040, speed 8550.07 words/sec, time elapsed 2567.70 sec
# epoch 6, iter 35230, avg. loss 32.25, avg. ppl 6.76 cum. examples 39360, speed 7760.67 words/sec, time elapsed 2568.40 sec
# epoch 6, iter 35240, avg. loss 31.05, avg. ppl 6.50 cum. examples 39680, speed 8025.40 words/sec, time elapsed 2569.06 sec
# epoch 6, iter 35250, avg. loss 33.73, avg. ppl 6.31 cum. examples 40000, speed 7781.37 words/sec, time elapsed 2569.81 sec
# epoch 6, iter 35260, avg. loss 31.13, avg. ppl 6.48 cum. examples 40320, speed 7659.74 words/sec, time elapsed 2570.51 sec
# ...

# %%
# !sh run.sh test
# Out:
# load test source sentences from [./en_es_data/test.es]
# load test target sentences from [./en_es_data/test.en]
# load model from model.bin
# Decoding:   0% 0/8064 [00:00<?, ?it/s]/pytorch/aten/src/ATen/native/BinaryOps.cpp:81: UserWarning: Integer division of tensors using div or / is deprecated, and in a future release div will perform true division as in Python 3. Use true_divide or floor_divide (// in Python) instead.
# Decoding: 100% 8064/8064 [06:15<00:00, 21.46it/s]
# Corpus BLEU: 22.45167811554719
